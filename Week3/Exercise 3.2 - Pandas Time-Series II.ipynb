# %% [markdown]
# # Data Science for Construction, Architecture and Engineering
#
# ### Week 3 - Construction - Pandas Time-Series Data
#
# ### Exercise Set 3.2 - Pandas Time-Series II
#
#  This exercise is related to the second half of Week 3 videos. Using the same data (Project Building Data Genome) and packages (Pandas) as in the videos, the following tasks about time-series data will be tested: normalize, fillna and merge.
#
# There is an introduction video available to explain the process of using this exercise video.
#
# The lead developer of this exercise is James Zhan Sicheng, a Ph.D. student at NUS and a teaching assistant of this course.

# %% [markdown]
# #### Setup the environment
# The cell below is used to load the necessary packages for this exercise and setup the working directory. You will be asked to give the google drive authorization using through a given link.

# %%
import pandas as pd
#from google.colab import drive
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# This time I want you to help me load the drive and change the directory to navigate to the place where the `all_buildings_meta_data.csv` file is:

# %%
# CODE GOES HERE TO MOUNT THE DRIVE 
#os.chdir

# %%
df = pd.read_csv("all_buildings_meta_data.csv",parse_dates=['dataend','datastart'])

# %%
df
# Out:
#                      uid             dataend  datastart  energystarscore  \
# 0      PrimClass_Everett 2012-12-31 23:00:00 2012-01-01              NaN
# 1     UnivClass_Clifford 2015-12-31 23:00:00 2015-01-01              NaN
# 2       Office_Elizabeth 2012-12-31 23:00:00 2012-01-01              NaN
# 3           Office_Ellie 2012-12-31 23:00:00 2012-01-01              NaN
# 4    PrimClass_Elisabeth 2012-12-31 23:00:00 2012-01-01              NaN
# ..                   ...                 ...        ...              ...
# 502          Office_Lane 2015-11-30 23:00:00 2014-01-12              NaN
# 503       Office_Cameron 2015-12-31 23:00:00 2015-01-01              NaN
# 504          UnivLab_Lea 2015-11-30 23:00:00 2014-01-12              NaN
# 505       UnivLab_Carlos 2015-12-31 23:00:00 2015-01-01              NaN
# 506        UnivLab_Aoife 2015-12-31 23:00:00 2015-01-01              NaN
#
#       heatingtype             industry mainheatingtype  numberoffloors  \
# ...

# %% [markdown]
# ## Exercise 03.2.1 - Filtering Meta Data
#
# Once again in this exercise, we want to focus on certain buildings found in the building data genome. This time we will give you the criteria and you write the code to filter the meta data.
#
# Adapt the code from the videos and the last exercise to filter buildings:
# - That use the file `weather7.csv`
# - That were built after *1960*
#
# Create a new DataFrame called `filtered` that holds a subset of the meta data file that meets the criteria listed above

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uid                     507 non-null    object
#  1   dataend                 507 non-null    datetime64[ns]
#  2   datastart               507 non-null    datetime64[ns]
#  3   energystarscore         26 non-null     float64
#  4   heatingtype             124 non-null    object
#  5   industry                507 non-null    object
#  6   mainheatingtype         122 non-null    object
#  7   numberoffloors          124 non-null    float64
#  8   occupants               105 non-null    float64
#  9   primaryspaceusage       506 non-null    object
#  10  rating                  132 non-null    object
#  11  sqft                    507 non-null    float64
#  12  sqm                     507 non-null    float64
#  13  subindustry             507 non-null    object
# ...

# %%
df.fillna(value=0,inplace=True)

# %%
df
# Out:
#                      uid             dataend  datastart  energystarscore  \
# 0      PrimClass_Everett 2012-12-31 23:00:00 2012-01-01              0.0
# 1     UnivClass_Clifford 2015-12-31 23:00:00 2015-01-01              0.0
# 2       Office_Elizabeth 2012-12-31 23:00:00 2012-01-01              0.0
# 3           Office_Ellie 2012-12-31 23:00:00 2012-01-01              0.0
# 4    PrimClass_Elisabeth 2012-12-31 23:00:00 2012-01-01              0.0
# ..                   ...                 ...        ...              ...
# 502          Office_Lane 2015-11-30 23:00:00 2014-01-12              0.0
# 503       Office_Cameron 2015-12-31 23:00:00 2015-01-01              0.0
# 504          UnivLab_Lea 2015-11-30 23:00:00 2014-01-12              0.0
# 505       UnivLab_Carlos 2015-12-31 23:00:00 2015-01-01              0.0
# 506        UnivLab_Aoife 2015-12-31 23:00:00 2015-01-01              0.0
#
#       heatingtype             industry mainheatingtype  numberoffloors  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uid                     507 non-null    object
#  1   dataend                 507 non-null    datetime64[ns]
#  2   datastart               507 non-null    datetime64[ns]
#  3   energystarscore         507 non-null    float64
#  4   heatingtype             507 non-null    object
#  5   industry                507 non-null    object
#  6   mainheatingtype         507 non-null    object
#  7   numberoffloors          507 non-null    float64
#  8   occupants               507 non-null    float64
#  9   primaryspaceusage       507 non-null    object
#  10  rating                  507 non-null    object
#  11  sqft                    507 non-null    float64
#  12  sqm                     507 non-null    float64
#  13  subindustry             507 non-null    object
# ...

# %%
df['yearbuilt'] = df['yearbuilt'].astype('int')

# %%
filtered = df[df['yearbuilt'] > 1960]

# %%
filtered
# Out:
#                     uid             dataend  datastart  energystarscore  \
# 1    UnivClass_Clifford 2015-12-31 23:00:00 2015-01-01              0.0
# 5       Office_Cristina 2015-12-31 23:00:00 2015-01-01              0.0
# 8          Office_Jesus 2015-11-30 23:00:00 2014-01-12              0.0
# 36      PrimClass_Jayla 2015-11-30 23:00:00 2014-01-12              0.0
# 38     PrimClass_Janiya 2015-11-30 23:00:00 2014-01-12              0.0
# ..                  ...                 ...        ...              ...
# 495      UnivLab_Carole 2015-12-31 23:00:00 2015-01-01              0.0
# 498      UnivLab_Dianna 2010-12-31 23:00:00 2010-01-01              0.0
# 499    UnivDorm_Cecilia 2015-12-31 23:00:00 2015-01-01              0.0
# 503      Office_Cameron 2015-12-31 23:00:00 2015-01-01              0.0
# 504         UnivLab_Lea 2015-11-30 23:00:00 2014-01-12              0.0
#
#     heatingtype    industry mainheatingtype  numberoffloors  occupants  \
# ...

# %%
filtered2 = filtered[filtered['newweatherfilename'] == 'weather7.csv']

# %%
filtered2
# Out:
#                  uid             dataend  datastart  energystarscore  \
# 86   UnivLab_Bethany 2012-12-31 23:00:00 2012-01-01              0.0
# 236    Office_Benthe 2012-12-31 23:00:00 2012-01-01              0.0
# 323     UnivLab_Beth 2012-12-31 23:00:00 2012-01-01              0.0
# 329    UnivClass_Bob 2012-12-31 23:00:00 2012-01-01              0.0
# 380     UnivLab_Brad 2012-12-31 23:00:00 2012-01-01              0.0
# 471     Office_Bryon 2012-12-31 23:00:00 2012-01-01              0.0
# 473   UnivLab_Brenna 2012-12-31 23:00:00 2012-01-01              0.0
#
#     heatingtype   industry mainheatingtype  numberoffloors  occupants  \
# 86            0  Education               0             0.0        0.0
# 236           0  Education               0             0.0        0.0
# 323           0  Education               0             0.0        0.0
# 329           0  Education               0             0.0        0.0
# ...

# %% [markdown]
# Now create a new DataFrame named `filtered_year` that includes only the following columns:
# - `primaryspaceusage`
# - `sqm`
# - `yearbuilt`

# %%
filtered_year = filtered2[['uid','datastart','primaryspaceusage','sqm','yearbuilt']]

# %%
filtered_year
# Out:
#                  uid  datastart   primaryspaceusage           sqm  yearbuilt
# 86   UnivLab_Bethany 2012-01-01  College Laboratory  18932.423660       1999
# 236    Office_Benthe 2012-01-01              Office  21947.590530       1962
# 323     UnivLab_Beth 2012-01-01  College Laboratory  16001.984330       1963
# 329    UnivClass_Bob 2012-01-01   College Classroom  11941.751620       1968
# 380     UnivLab_Brad 2012-01-01  College Laboratory  11608.229850       1961
# 471     Office_Bryon 2012-01-01              Office   9069.005054       1964
# 473   UnivLab_Brenna 2012-01-01  College Laboratory   8102.628048       1964

# %%
filtered_year.reset_index(drop=True,inplace=True)

# %%
filtered_year
# Out:
#                uid  datastart   primaryspaceusage           sqm  yearbuilt
# 0  UnivLab_Bethany 2012-01-01  College Laboratory  18932.423660       1999
# 1    Office_Benthe 2012-01-01              Office  21947.590530       1962
# 2     UnivLab_Beth 2012-01-01  College Laboratory  16001.984330       1963
# 3    UnivClass_Bob 2012-01-01   College Classroom  11941.751620       1968
# 4     UnivLab_Brad 2012-01-01  College Laboratory  11608.229850       1961
# 5     Office_Bryon 2012-01-01              Office   9069.005054       1964
# 6   UnivLab_Brenna 2012-01-01  College Laboratory   8102.628048       1964

# %%
filtered_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   uid                7 non-null      object
#  1   datastart          7 non-null      datetime64[ns]
#  2   primaryspaceusage  7 non-null      object
#  3   sqm                7 non-null      float64
#  4   yearbuilt          7 non-null      int32
# dtypes: datetime64[ns](1), float64(1), int32(1), object(2)
# memory usage: 380.0+ bytes

# %% [markdown]
# Now load the meter data for these buildings and this time use the `.merge()` function from Pandas.
#
# Hint: When you merge files, sometimes you can end up with duplicate rows -- in this case, you can use the [`.drop_duplicates()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) function to remove duplications. You should end up with a DataFrame with 8783 rows.
#
# Create a variable called `meter_data` to hold the resultant DataFrame

# %%
Bethany = pd.read_csv("UnivLab_Bethany.csv", parse_dates=['timestamp'])

# %%
Bethany
# Out:
#                timestamp  UnivLab_Bethany
# 0    2012-01-01 00:00:00         52.76875
# 1    2012-01-01 01:00:00         51.55575
# 2    2012-01-01 02:00:00         51.85475
# 3    2012-01-01 03:00:00         51.87725
# 4    2012-01-01 04:00:00         51.86200
# ...                  ...              ...
# 8779 2012-12-31 19:00:00         65.27875
# 8780 2012-12-31 20:00:00         65.85125
# 8781 2012-12-31 21:00:00         63.51900
# 8782 2012-12-31 22:00:00         61.89100
# 8783 2012-12-31 23:00:00         66.73125
#
# [8784 rows x 2 columns]

# %%
Bethany.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   timestamp        8784 non-null   datetime64[ns]
#  1   UnivLab_Bethany  8784 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 137.4 KB

# %%
Benthe = pd.read_csv("Office_Benthe.csv")

# %%
Benthe
# Out:
#                 timestamp  Office_Benthe
# 0     2012-01-01 00:00:00         142.25
# 1     2012-01-01 01:00:00         143.00
# 2     2012-01-01 02:00:00         160.00
# 3     2012-01-01 03:00:00         166.00
# 4     2012-01-01 04:00:00         142.50
# ...                   ...            ...
# 8779  2012-12-31 19:00:00         142.25
# 8780  2012-12-31 20:00:00         140.50
# 8781  2012-12-31 21:00:00         139.25
# 8782  2012-12-31 22:00:00         139.25
# 8783  2012-12-31 23:00:00         145.00
#
# [8784 rows x 2 columns]

# %%
Benthe.drop(['timestamp'],axis=1,inplace=True)

# %%
Benthe
# Out:
#       Office_Benthe
# 0            142.25
# 1            143.00
# 2            160.00
# 3            166.00
# 4            142.50
# ...             ...
# 8779         142.25
# 8780         140.50
# 8781         139.25
# 8782         139.25
# 8783         145.00
#
# [8784 rows x 1 columns]

# %%
Benthe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Office_Benthe  8784 non-null   float64
# dtypes: float64(1)
# memory usage: 68.8 KB

# %%
Beth = pd.read_csv("UnivLab_Beth.csv")

# %%
Beth.drop(['timestamp'],axis=1,inplace=True)

# %%
Beth
# Out:
#       UnivLab_Beth
# 0          182.675
# 1          185.125
# 2          180.325
# 3          181.500
# 4          176.400
# ...            ...
# 8779       158.250
# 8780       159.500
# 8781       160.475
# 8782       157.250
# 8783       157.275
#
# [8784 rows x 1 columns]

# %%
Bob = pd.read_csv("UnivClass_Bob.csv")

# %%
Bob.drop(['timestamp'],axis=1,inplace=True)

# %%
Bob
# Out:
#       UnivClass_Bob
# 0           226.700
# 1           183.200
# 2           124.025
# 3            92.325
# 4            84.450
# ...             ...
# 8779        231.875
# 8780        240.600
# 8781        240.075
# 8782        241.625
# 8783        235.325
#
# [8784 rows x 1 columns]

# %%
Brad = pd.read_csv("UnivLab_Brad.csv")

# %%
Brad.drop(['timestamp'],axis=1,inplace=True)

# %%
Brad
# Out:
#       UnivLab_Brad
# 0          182.025
# 1          194.925
# 2          194.525
# 3          193.450
# 4          186.575
# ...            ...
# 8779       178.050
# 8780       181.675
# 8781       182.850
# 8782       186.775
# 8783       176.575
#
# [8784 rows x 1 columns]

# %%
Bryon = pd.read_csv("Office_Bryon.csv")

# %%
Bryon.drop(['timestamp'],axis=1,inplace=True)

# %%
Bryon
# Out:
#       Office_Bryon
# 0          273.150
# 1          267.925
# 2          267.725
# 3          266.425
# 4          263.250
# ...            ...
# 8779       260.300
# 8780       295.075
# 8781       302.450
# 8782       309.000
# 8783       302.925
#
# [8784 rows x 1 columns]

# %%
Brenna = pd.read_csv("UnivLab_Brenna.csv")

# %%
Brenna.drop(['timestamp'],axis=1,inplace=True)

# %%
Brenna
# Out:
#       UnivLab_Brenna
# 0             295.00
# 1             299.50
# 2             286.50
# 3             290.75
# 4             290.75
# ...              ...
# 8779          281.00
# 8780          283.25
# 8781          279.00
# 8782          286.75
# 8783          289.75
#
# [8784 rows x 1 columns]

# %%
allmeters = pd.concat([Bethany,Benthe,Beth,Bob,Brad,Bryon,Brenna],axis=1)

# %%
allmeters
# Out:
#                timestamp  UnivLab_Bethany  Office_Benthe  UnivLab_Beth  \
# 0    2012-01-01 00:00:00         52.76875         142.25       182.675
# 1    2012-01-01 01:00:00         51.55575         143.00       185.125
# 2    2012-01-01 02:00:00         51.85475         160.00       180.325
# 3    2012-01-01 03:00:00         51.87725         166.00       181.500
# 4    2012-01-01 04:00:00         51.86200         142.50       176.400
# ...                  ...              ...            ...           ...
# 8779 2012-12-31 19:00:00         65.27875         142.25       158.250
# 8780 2012-12-31 20:00:00         65.85125         140.50       159.500
# 8781 2012-12-31 21:00:00         63.51900         139.25       160.475
# 8782 2012-12-31 22:00:00         61.89100         139.25       157.250
# 8783 2012-12-31 23:00:00         66.73125         145.00       157.275
#
#       UnivClass_Bob  UnivLab_Brad  Office_Bryon  UnivLab_Brenna
# ...

# %%
meter_data = allmeters

# %%
meter_data
# Out:
#                timestamp  UnivLab_Bethany  Office_Benthe  UnivLab_Beth  \
# 0    2012-01-01 00:00:00         52.76875         142.25       182.675
# 1    2012-01-01 01:00:00         51.55575         143.00       185.125
# 2    2012-01-01 02:00:00         51.85475         160.00       180.325
# 3    2012-01-01 03:00:00         51.87725         166.00       181.500
# 4    2012-01-01 04:00:00         51.86200         142.50       176.400
# ...                  ...              ...            ...           ...
# 8779 2012-12-31 19:00:00         65.27875         142.25       158.250
# 8780 2012-12-31 20:00:00         65.85125         140.50       159.500
# 8781 2012-12-31 21:00:00         63.51900         139.25       160.475
# 8782 2012-12-31 22:00:00         61.89100         139.25       157.250
# 8783 2012-12-31 23:00:00         66.73125         145.00       157.275
#
#       UnivClass_Bob  UnivLab_Brad  Office_Bryon  UnivLab_Brenna
# ...

# %% [markdown]
# ### Exercise 03.2.2 - Normalization and Finding Highest Consuming Building
#
# As you learned in the videos, it is straightforward to create area normalized calculations. In this excerice, go ahead and give that a try on the `meter_data` DataFrame that you created from the list of filtered buildings in the previous exercise.
#
# In this exerise, use the merged dataset from the last task to:
# 1. Calculate the daily energy consumption normalized by floor area (`sqm`) for each building
# 2. Identify the building with the most number of days that consume the most normalized energy as compared to the rest of the buildings
#
# First, try normalizing the daily data for the `meter_data` DataFrame by dividing by the floor area (`sqm`)

# %%
filtered_year
# Out:
#                uid  datastart   primaryspaceusage           sqm  yearbuilt
# 0  UnivLab_Bethany 2012-01-01  College Laboratory  18932.423660       1999
# 1    Office_Benthe 2012-01-01              Office  21947.590530       1962
# 2     UnivLab_Beth 2012-01-01  College Laboratory  16001.984330       1963
# 3    UnivClass_Bob 2012-01-01   College Classroom  11941.751620       1968
# 4     UnivLab_Brad 2012-01-01  College Laboratory  11608.229850       1961
# 5     Office_Bryon 2012-01-01              Office   9069.005054       1964
# 6   UnivLab_Brenna 2012-01-01  College Laboratory   8102.628048       1964

# %%
meter_data['BethanyNorm'] = meter_data['UnivLab_Bethany']/18932.423660

# %%
meter_data['BentheNorm'] = meter_data['Office_Benthe']/21947.590530

# %%
meter_data['BethNorm'] = meter_data['UnivLab_Beth']/16001.984330

# %%
meter_data['BobNorm'] = meter_data['UnivClass_Bob']/11941.751620

# %%
meter_data['BradNorm'] = meter_data['UnivLab_Brad']/11608.229850

# %%
meter_data['BryonNorm'] = meter_data['Office_Bryon']/9069.005054

# %%
meter_data['BrennaNorm'] = meter_data['UnivLab_Brenna']/8102.628048

# %%
meter_data
# Out:
#                timestamp  UnivLab_Bethany  Office_Benthe  UnivLab_Beth  \
# 0    2012-01-01 00:00:00         52.76875         142.25       182.675
# 1    2012-01-01 01:00:00         51.55575         143.00       185.125
# 2    2012-01-01 02:00:00         51.85475         160.00       180.325
# 3    2012-01-01 03:00:00         51.87725         166.00       181.500
# 4    2012-01-01 04:00:00         51.86200         142.50       176.400
# ...                  ...              ...            ...           ...
# 8779 2012-12-31 19:00:00         65.27875         142.25       158.250
# 8780 2012-12-31 20:00:00         65.85125         140.50       159.500
# 8781 2012-12-31 21:00:00         63.51900         139.25       160.475
# 8782 2012-12-31 22:00:00         61.89100         139.25       157.250
# 8783 2012-12-31 23:00:00         66.73125         145.00       157.275
#
#       UnivClass_Bob  UnivLab_Brad  Office_Bryon  UnivLab_Brenna  BethanyNorm  \
# ...

# %% [markdown]
# Now, the task is to find the building which has the most number of days in which it has the *highest* daily normalized energy consumption as compared to the other buildings in the DataFrame. This information could be used to find the *worst* performing building in terms of number of day
#
# Hint: the [`.idxmax()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.idxmax.html) is useful to find the maximum value across an axis and the and [`.value_counts()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html) could be useful for finding the frequency counts

# %%
meter_data.columns
# Out:
# Index(['timestamp', 'UnivLab_Bethany', 'Office_Benthe', 'UnivLab_Beth',
#        'UnivClass_Bob', 'UnivLab_Brad', 'Office_Bryon', 'UnivLab_Brenna',
#        'BethanyNorm', 'BentheNorm', 'BethNorm', 'BobNorm', 'BradNorm',
#        'BryonNorm', 'BrennaNorm'],
#       dtype='object')

# %%
meter_data['BethanyNorm'].idxmax()
# Out:
# 766

# %%
meter_data['BethanyNorm'].max()
# Out:
# 0.006591218971274595

# %%
meter_data['BethanyNorm'].value_counts()
# Out:
# 0.003288    3
# 0.003165    3
# 0.003348    3
# 0.003630    3
# 0.003686    3
#            ..
# 0.004253    1
# 0.002976    1
# 0.003634    1
# 0.003452    1
# 0.003691    1
# Name: BethanyNorm, Length: 8546, dtype: int64

# %%
meter_data.loc[766]
# Out:
# timestamp          2012-02-01 22:00:00
# UnivLab_Bethany                124.788
# Office_Benthe                    344.5
# UnivLab_Beth                   270.175
# UnivClass_Bob                    258.4
# UnivLab_Brad                    248.15
# Office_Bryon                   380.325
# UnivLab_Brenna                   344.5
# BethanyNorm                 0.00659122
# BentheNorm                   0.0156965
# BethNorm                     0.0168838
# BobNorm                      0.0216384
# BradNorm                     0.0213771
# BryonNorm                    0.0419368
# BrennaNorm                   0.0425171
# Name: 766, dtype: object

# %% [markdown]
# ### Repeat the same for other buildings

# %% [markdown]
# ### Exercise 03.2.3 - Outliers and Filtering Quantities
#
# In this next exercise, let's look at the weather file that is associated with these buildings 'weather7.csv`
#
# There are two parts to this exercise -- the first is to identify the dates with outliers in the `TemperatureC` column according to the method from the videos
#
# To do this first part, plot the data to get a sense of the situation and then write a bit of code that filters out the days with outliers

# %%
weather = pd.read_csv("weather7.csv")

# %%
weather
# Out:
#                  timestamp     Conditions              DateUTC<br />  \
# 0      2012-01-01 00:15:00          Clear  2012-01-01 06:15:00<br />
# 1      2012-01-01 00:55:00          Clear  2012-01-01 06:55:00<br />
# 2      2012-01-01 01:15:00          Clear  2012-01-01 07:15:00<br />
# 3      2012-01-01 01:35:00          Clear  2012-01-01 07:35:00<br />
# 4      2012-01-01 02:15:00          Clear  2012-01-01 08:15:00<br />
# ...                    ...            ...                        ...
# 25142  2012-12-31 22:35:00  Mostly Cloudy  2013-01-01 04:35:00<br />
# 25143  2012-12-31 22:55:00       Overcast  2013-01-01 04:55:00<br />
# 25144  2012-12-31 23:15:00       Overcast  2013-01-01 05:15:00<br />
# 25145  2012-12-31 23:35:00       Overcast  2013-01-01 05:35:00<br />
# 25146  2012-12-31 23:55:00       Overcast  2013-01-01 05:55:00<br />
#
#        Dew PointC Events Gust SpeedKm/h  Humidity  Precipitationmm  \
# 0            -2.0    NaN           25.9      70.0              NaN
# ...

# %%
sns.distplot(weather['TemperatureC'],bins=20,kde=False);

# %%
weather.describe()
# Out:
#          Dew PointC      Humidity  Precipitationmm  Sea Level PressurehPa  \
# count  25147.000000  24795.000000       475.000000           25147.000000
# mean    -134.385406     63.692478         0.069137            1012.161709
# std     1175.419225     22.193391         0.129042             183.884974
# min    -9999.000000     12.000000         0.010000           -9999.000000
# 25%       -2.000000     46.000000         0.010000            1010.400000
# 50%        6.100000     66.000000         0.020000            1015.100000
# 75%       14.000000     83.000000         0.060000            1019.900000
# max       25.400000    100.000000         1.000000            1042.200000
#
#        TemperatureC  VisibilityKm  WindDirDegrees
# count  25147.000000  25147.000000    25147.000000
# mean    -126.505977      8.085386      146.837396
# std     1176.375467    267.848224      119.854093
# min    -9999.000000  -9999.000000        0.000000
# ...

# %% [markdown]
# You can see that there are several days which have outliers. Find the which days have outliers.
#
# Hint: You can filter out the outlier rows and the `.resample()`, `.dropna()` and the `.index` will be helpful

# %%
tempoutliers = weather[weather['TemperatureC'] == -9999]

# %%
tempoutliers
# Out:
#                  timestamp Conditions              DateUTC<br />  Dew PointC  \
# 2355   2012-02-04 06:35:00    Unknown  2012-02-04 12:35:00<br />     -9999.0
# 2356   2012-02-04 06:55:00    Unknown  2012-02-04 12:55:00<br />     -9999.0
# 2357   2012-02-04 07:15:00    Unknown  2012-02-04 13:15:00<br />     -9999.0
# 2376   2012-02-04 13:35:00    Unknown  2012-02-04 19:35:00<br />     -9999.0
# 2379   2012-02-04 14:35:00    Unknown  2012-02-04 20:35:00<br />     -9999.0
# ...                    ...        ...                        ...         ...
# 8860   2012-05-10 14:15:00    Unknown  2012-05-10 19:15:00<br />     -9999.0
# 11714  2012-06-20 14:15:00    Unknown  2012-06-20 19:15:00<br />     -9999.0
# 11715  2012-06-20 14:35:00   Overcast  2012-06-20 19:35:00<br />     -9999.0
# 17604  2012-09-13 13:35:00    Unknown  2012-09-13 18:35:00<br />     -9999.0
# 17605  2012-09-13 13:55:00    Unknown  2012-09-13 18:55:00<br />     -9999.0
#
# ...

# %% [markdown]
# In the second part of this exercise, find the month that has the *lowest* average `Wind SpeedKm/h` (`calm` can be considered as 0 `km/h`).
#
# Hints:
# - The pandas function [`to_numeric`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_numeric.html) is useful to convert strings to numbers. Remember that there are attributes for this function that might be necessary to use if you get an error.
# - Note that negative wind speed is unreasonable and should be removed
# - `.resample()` can also be useful for the calculation, note again that `calm` should be taken into consideration as 0 instead of `np.nan` (not a number) when calculating the average
# - [`.fillna()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html) is useful for replacing blanks in the data

# %%
weather.columns
# Out:
# Index(['timestamp', 'Conditions', 'DateUTC<br />', 'Dew PointC', 'Events',
#        'Gust SpeedKm/h', 'Humidity', 'Precipitationmm',
#        'Sea Level PressurehPa', 'TemperatureC', 'TimeCDT', 'TimeCST',
#        'VisibilityKm', 'Wind Direction', 'Wind SpeedKm/h', 'WindDirDegrees',
#        'timestamp.1'],
#       dtype='object')

# %%
weather['Wind SpeedKm/h']
# Out:
# 0        14.8
# 1        24.1
# 2        25.9
# 3        25.9
# 4        22.2
#          ...
# 25142     5.6
# 25143     5.6
# 25144     5.6
# 25145    Calm
# 25146     7.4
# Name: Wind SpeedKm/h, Length: 25147, dtype: object

# %%
weather['Wind SpeedKm/h'].value_counts()
# Out:
# Calm       6082
# 9.3        1982
# 7.4        1968
# 5.6        1899
# 11.1       1790
# 13.0       1726
# 14.8       1622
# 16.7       1403
# 18.5       1185
# 20.4       1120
# 22.2        922
# 24.1        740
# 25.9        641
# 27.8        485
# 29.6        418
# 31.5        317
# 33.3        236
# 35.2        177
# 37.0        111
# 38.9         89
# 40.7         87
# 42.6         49
# 44.4         32
# 48.2         17
# 46.3         16
# 50.0         15
# -9999.0      10
# 51.9          3
# 53.7          3
# 55.6          2
# Name: Wind SpeedKm/h, dtype: int64

# %%
weather['Wind SpeedKm/h'] = weather['Wind SpeedKm/h'].replace(to_replace='Calm',value=0)

# %%
weather['Wind SpeedKm/h'].value_counts()
# Out:
# 0          6082
# 9.3        1982
# 7.4        1968
# 5.6        1899
# 11.1       1790
# 13.0       1726
# 14.8       1622
# 16.7       1403
# 18.5       1185
# 20.4       1120
# 22.2        922
# 24.1        740
# 25.9        641
# 27.8        485
# 29.6        418
# 31.5        317
# 33.3        236
# 35.2        177
# 37.0        111
# 38.9         89
# 40.7         87
# 42.6         49
# 44.4         32
# 48.2         17
# 46.3         16
# 50.0         15
# -9999.0      10
# 51.9          3
# 53.7          3
# 55.6          2
# Name: Wind SpeedKm/h, dtype: int64

# %%
newdf = weather[weather['Wind SpeedKm/h'] != '-9999.0']

# %%
newdf
# Out:
#                  timestamp     Conditions              DateUTC<br />  \
# 0      2012-01-01 00:15:00          Clear  2012-01-01 06:15:00<br />
# 1      2012-01-01 00:55:00          Clear  2012-01-01 06:55:00<br />
# 2      2012-01-01 01:15:00          Clear  2012-01-01 07:15:00<br />
# 3      2012-01-01 01:35:00          Clear  2012-01-01 07:35:00<br />
# 4      2012-01-01 02:15:00          Clear  2012-01-01 08:15:00<br />
# ...                    ...            ...                        ...
# 25142  2012-12-31 22:35:00  Mostly Cloudy  2013-01-01 04:35:00<br />
# 25143  2012-12-31 22:55:00       Overcast  2013-01-01 04:55:00<br />
# 25144  2012-12-31 23:15:00       Overcast  2013-01-01 05:15:00<br />
# 25145  2012-12-31 23:35:00       Overcast  2013-01-01 05:35:00<br />
# 25146  2012-12-31 23:55:00       Overcast  2013-01-01 05:55:00<br />
#
#        Dew PointC Events Gust SpeedKm/h  Humidity  Precipitationmm  \
# 0            -2.0    NaN           25.9      70.0              NaN
# ...

# %%
newdf['Wind SpeedKm/h'].value_counts()
# Out:
# 0       6082
# 9.3     1982
# 7.4     1968
# 5.6     1899
# 11.1    1790
# 13.0    1726
# 14.8    1622
# 16.7    1403
# 18.5    1185
# 20.4    1120
# 22.2     922
# 24.1     740
# 25.9     641
# 27.8     485
# 29.6     418
# 31.5     317
# 33.3     236
# 35.2     177
# 37.0     111
# 38.9      89
# 40.7      87
# 42.6      49
# 44.4      32
# 48.2      17
# 46.3      16
# 50.0      15
# 51.9       3
# 53.7       3
# 55.6       2
# Name: Wind SpeedKm/h, dtype: int64

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25137 entries, 0 to 25146
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   timestamp              25137 non-null  object
#  1   Conditions             25137 non-null  object
#  2   DateUTC<br />          25137 non-null  object
#  3   Dew PointC             25137 non-null  float64
#  4   Events                 1055 non-null   object
#  5   Gust SpeedKm/h         25137 non-null  object
#  6   Humidity               24789 non-null  float64
#  7   Precipitationmm        475 non-null    float64
#  8   Sea Level PressurehPa  25137 non-null  float64
#  9   TemperatureC           25137 non-null  float64
#  10  TimeCDT                16300 non-null  object
#  11  TimeCST                8837 non-null   object
#  12  VisibilityKm           25137 non-null  float64
#  13  Wind Direction         25137 non-null  object
# ...

# %%
newdf['Wind SpeedKm/h'] = pd.to_numeric(newdf['Wind SpeedKm/h'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25137 entries, 0 to 25146
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   timestamp              25137 non-null  object
#  1   Conditions             25137 non-null  object
#  2   DateUTC<br />          25137 non-null  object
#  3   Dew PointC             25137 non-null  float64
#  4   Events                 1055 non-null   object
#  5   Gust SpeedKm/h         25137 non-null  object
#  6   Humidity               24789 non-null  float64
#  7   Precipitationmm        475 non-null    float64
#  8   Sea Level PressurehPa  25137 non-null  float64
#  9   TemperatureC           25137 non-null  float64
#  10  TimeCDT                16300 non-null  object
#  11  TimeCST                8837 non-null   object
#  12  VisibilityKm           25137 non-null  float64
#  13  Wind Direction         25137 non-null  object
# ...

# %%
len(newdf['Wind SpeedKm/h'])
# Out:
# 25137

# %%
newdf
# Out:
#                  timestamp     Conditions              DateUTC<br />  \
# 0      2012-01-01 00:15:00          Clear  2012-01-01 06:15:00<br />
# 1      2012-01-01 00:55:00          Clear  2012-01-01 06:55:00<br />
# 2      2012-01-01 01:15:00          Clear  2012-01-01 07:15:00<br />
# 3      2012-01-01 01:35:00          Clear  2012-01-01 07:35:00<br />
# 4      2012-01-01 02:15:00          Clear  2012-01-01 08:15:00<br />
# ...                    ...            ...                        ...
# 25142  2012-12-31 22:35:00  Mostly Cloudy  2013-01-01 04:35:00<br />
# 25143  2012-12-31 22:55:00       Overcast  2013-01-01 04:55:00<br />
# 25144  2012-12-31 23:15:00       Overcast  2013-01-01 05:15:00<br />
# 25145  2012-12-31 23:35:00       Overcast  2013-01-01 05:35:00<br />
# 25146  2012-12-31 23:55:00       Overcast  2013-01-01 05:55:00<br />
#
#        Dew PointC Events Gust SpeedKm/h  Humidity  Precipitationmm  \
# 0            -2.0    NaN           25.9      70.0              NaN
# ...

# %%
df2 = newdf[newdf['Wind SpeedKm/h'] != 0]

# %%
df2['Wind SpeedKm/h'].value_counts()
# Out:
# 9.3     1982
# 7.4     1968
# 5.6     1899
# 11.1    1790
# 13.0    1726
# 14.8    1622
# 16.7    1403
# 18.5    1185
# 20.4    1120
# 22.2     922
# 24.1     740
# 25.9     641
# 27.8     485
# 29.6     418
# 31.5     317
# 33.3     236
# 35.2     177
# 37.0     111
# 38.9      89
# 40.7      87
# 42.6      49
# 44.4      32
# 48.2      17
# 46.3      16
# 50.0      15
# 51.9       3
# 53.7       3
# 55.6       2
# Name: Wind SpeedKm/h, dtype: int64

# %%
df2
# Out:
#                  timestamp        Conditions              DateUTC<br />  \
# 0      2012-01-01 00:15:00             Clear  2012-01-01 06:15:00<br />
# 1      2012-01-01 00:55:00             Clear  2012-01-01 06:55:00<br />
# 2      2012-01-01 01:15:00             Clear  2012-01-01 07:15:00<br />
# 3      2012-01-01 01:35:00             Clear  2012-01-01 07:35:00<br />
# 4      2012-01-01 02:15:00             Clear  2012-01-01 08:15:00<br />
# ...                    ...               ...                        ...
# 25141  2012-12-31 22:15:00  Scattered Clouds  2013-01-01 04:15:00<br />
# 25142  2012-12-31 22:35:00     Mostly Cloudy  2013-01-01 04:35:00<br />
# 25143  2012-12-31 22:55:00          Overcast  2013-01-01 04:55:00<br />
# 25144  2012-12-31 23:15:00          Overcast  2013-01-01 05:15:00<br />
# 25146  2012-12-31 23:55:00          Overcast  2013-01-01 05:55:00<br />
#
#        Dew PointC Events Gust SpeedKm/h  Humidity  Precipitationmm  \
# ...

# %%
df2.reset_index(drop=True,inplace=True)

# %%
df2
# Out:
#                  timestamp        Conditions              DateUTC<br />  \
# 0      2012-01-01 00:15:00             Clear  2012-01-01 06:15:00<br />
# 1      2012-01-01 00:55:00             Clear  2012-01-01 06:55:00<br />
# 2      2012-01-01 01:15:00             Clear  2012-01-01 07:15:00<br />
# 3      2012-01-01 01:35:00             Clear  2012-01-01 07:35:00<br />
# 4      2012-01-01 02:15:00             Clear  2012-01-01 08:15:00<br />
# ...                    ...               ...                        ...
# 19050  2012-12-31 22:15:00  Scattered Clouds  2013-01-01 04:15:00<br />
# 19051  2012-12-31 22:35:00     Mostly Cloudy  2013-01-01 04:35:00<br />
# 19052  2012-12-31 22:55:00          Overcast  2013-01-01 04:55:00<br />
# 19053  2012-12-31 23:15:00          Overcast  2013-01-01 05:15:00<br />
# 19054  2012-12-31 23:55:00          Overcast  2013-01-01 05:55:00<br />
#
#        Dew PointC Events Gust SpeedKm/h  Humidity  Precipitationmm  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19055 entries, 0 to 19054
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   timestamp              19055 non-null  object
#  1   Conditions             19055 non-null  object
#  2   DateUTC<br />          19055 non-null  object
#  3   Dew PointC             19055 non-null  float64
#  4   Events                 905 non-null    object
#  5   Gust SpeedKm/h         19055 non-null  object
#  6   Humidity               18854 non-null  float64
#  7   Precipitationmm        439 non-null    float64
#  8   Sea Level PressurehPa  19055 non-null  float64
#  9   TemperatureC           19055 non-null  float64
#  10  TimeCDT                12494 non-null  object
#  11  TimeCST                6561 non-null   object
#  12  VisibilityKm           19055 non-null  float64
#  13  Wind Direction         19055 non-null  object
# ...

# %%
df2['Wind SpeedKm/h'].min()
# Out:
# 5.6

# %%
lowestaverage = df2[df2['Wind SpeedKm/h'] == 5.6]

# %%
lowestaverage
# Out:
#                  timestamp     Conditions              DateUTC<br />  \
# 9      2012-01-01 03:55:00          Clear  2012-01-01 09:55:00<br />
# 13     2012-01-01 10:55:00          Clear  2012-01-01 16:55:00<br />
# 56     2012-01-03 14:55:00          Clear  2012-01-03 20:55:00<br />
# 59     2012-01-04 01:55:00          Clear  2012-01-04 07:55:00<br />
# 66     2012-01-04 06:55:00          Clear  2012-01-04 12:55:00<br />
# ...                    ...            ...                        ...
# 18990  2012-12-30 22:55:00          Clear  2012-12-31 04:55:00<br />
# 18992  2012-12-31 00:55:00       Overcast  2012-12-31 06:55:00<br />
# 19051  2012-12-31 22:35:00  Mostly Cloudy  2013-01-01 04:35:00<br />
# 19052  2012-12-31 22:55:00       Overcast  2013-01-01 04:55:00<br />
# 19053  2012-12-31 23:15:00       Overcast  2013-01-01 05:15:00<br />
#
#        Dew PointC Events Gust SpeedKm/h  Humidity  Precipitationmm  \
# 9            -4.0    NaN              -      70.0              NaN
# ...
